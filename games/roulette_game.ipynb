# %%
<!DOCTYPE html>
<html lang="de">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Roulette Spiel</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'Arial', sans-serif;
            background: linear-gradient(135deg, #1e3c72, #2a5298);
            color: white;
            min-height: 100vh;
            display: flex;
            flex-direction: column;
            align-items: center;
            padding: 20px;
        }

        .game-container {
            max-width: 1200px;
            width: 100%;
        }

        .wheel-container {
            display: flex;
            justify-content: center;
            margin-bottom: 40px;
            position: relative;
        }

        .roulette-wheel {
            width: 400px;
            height: 400px;
            border-radius: 50%;
            background: #8B4513;
            border: 10px solid #654321;
            position: relative;
            margin: 20px;
            box-shadow: 0 0 30px rgba(0, 0, 0, 0.5);
        }

        .wheel-numbers {
            width: 100%;
            height: 100%;
            border-radius: 50%;
            position: relative;
            overflow: hidden;
        }

        .number-segment {
            position: absolute;
            width: 50%;
            height: 2px;
            top: 50%;
            left: 50%;
            transform-origin: 0 0;
            display: flex;
            align-items: center;
            justify-content: flex-end;
            padding-right: 25px;
            font-weight: bold;
            font-size: 12px;
            color: white;
            text-shadow: 1px 1px 1px rgba(0, 0, 0, 0.8);
        }

        .number-segment.red {
            background: linear-gradient(90deg, transparent 0%, transparent 75%, #dc143c 75%, #dc143c 100%);
        }

        .number-segment.black {
            background: linear-gradient(90deg, transparent 0%, transparent 75%, #000000 75%, #000000 100%);
        }

        .number-segment.green {
            background: linear-gradient(90deg, transparent 0%, transparent 75%, #228b22 75%, #228b22 100%);
        }

        .ball {
            width: 12px;
            height: 12px;
            background: white;
            border-radius: 50%;
            position: absolute;
            top: 15px;
            left: 50%;
            transform: translateX(-50%);
            box-shadow: 0 0 10px rgba(255, 255, 255, 0.8);
            z-index: 10;
        }

        .ball.spinning {
            animation: spin-ball 3s cubic-bezier(0.25, 0.46, 0.45, 0.94) forwards;
        }

        @keyframes spin-ball {
            0% { transform: translateX(-50%) rotate(0deg) translateX(185px) rotate(0deg); }
            100% { transform: translateX(-50%) rotate(1800deg) translateX(185px) rotate(-1800deg); }
        }

        .center-circle {
            width: 60px;
            height: 60px;
            background: #654321;
            border-radius: 50%;
            position: absolute;
            top: 50%;
            left: 50%;
            transform: translate(-50%, -50%);
            border: 3px solid #8B4513;
        }

        .betting-table {
            background: #0f5132;
            border-radius: 10px;
            padding: 20px;
            margin-bottom: 30px;
            border: 3px solid #198754;
        }

        .betting-grid {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(40px, 1fr));
            gap: 5px;
            max-width: 800px;
            margin: 0 auto;
        }

        .bet-number {
            width: 40px;
            height: 40px;
            display: flex;
            align-items: center;
            justify-content: center;
            border: 2px solid #fff;
            cursor: pointer;
            font-weight: bold;
            transition: all 0.3s ease;
        }

        .bet-number.red {
            background: #dc143c;
            color: white;
        }

        .bet-number.black {
            background: #000;
            color: white;
        }

        .bet-number.green {
            background: #228b22;
            color: white;
        }

        .bet-number:hover {
            transform: scale(1.1);
            box-shadow: 0 0 15px rgba(255, 255, 255, 0.8);
        }

        .players-section {
            background: rgba(255, 255, 255, 0.1);
            border-radius: 10px;
            padding: 20px;
            margin-bottom: 20px;
        }

        .add-player {
            display: flex;
            gap: 10px;
            margin-bottom: 20px;
            flex-wrap: wrap;
        }

        .add-player input, .add-player select, .add-player button {
            padding: 10px;
            border: none;
            border-radius: 5px;
            font-size: 16px;
        }

        .add-player input {
            flex: 1;
            min-width: 200px;
        }

        .add-player button {
            background: #28a745;
            color: white;
            cursor: pointer;
            transition: background 0.3s ease;
        }

        .add-player button:hover {
            background: #218838;
        }

        .players-list {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
            gap: 15px;
        }

        .player-card {
            background: rgba(255, 255, 255, 0.2);
            border-radius: 8px;
            padding: 15px;
            display: flex;
            justify-content: space-between;
            align-items: center;
        }

        .player-info {
            flex: 1;
        }

        .player-actions {
            display: flex;
            gap: 5px;
        }

        .btn {
            padding: 8px 12px;
            border: none;
            border-radius: 4px;
            cursor: pointer;
            font-size: 14px;
            transition: all 0.3s ease;
        }

        .btn-edit {
            background: #ffc107;
            color: #000;
        }

        .btn-delete {
            background: #dc3545;
            color: white;
        }

        .btn:hover {
            transform: translateY(-2px);
